# %% [markdown]
# # Lucra Science Demo NotebookWelcome to the **Lucra Science** themed notebook running on Binder.This notebook is just a quick demo to see how your custom Jupyter theme looks.

# %% [markdown]
# ## 1. Markdown stylingThis is a markdown cell. With your custom theme applied, you should see:- Dark background- Brand colours (navy / cyan / gold)Try editing this text or adding new markdown cells to see how they look.

# %% [markdown]
# ## 2. Code cell stylingRun the cell below to test code and output styling.

# %%
message = 'Lucra Science Theme Test Successful!'print(message)

# %% [markdown]
# ## 3. Simple data exampleRun the cell below to see a small pandas DataFrame.

# %%
import pandas as pddf = pd.DataFrame({    'Feature': ['Speed', 'Brand Colour', 'Quality'],    'Value': ['Fast', 'Navy / Cyan / Gold', 'Premium']})df
