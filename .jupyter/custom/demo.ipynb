# %% [markdown]
# # <span style="color:#00e5ff; font-weight:700;">Lucra Science</span>
# ### <span style="color:#f5c045;">Innovating Tomorrow's Technologies</span>
#
# Welcome to the **Lucra Science custom-themed Jupyter Notebook**.
#
# This notebook demonstrates how your **branded theme** looks when rendered on Binder.
#
# ---

# %% [markdown]
# ## <span style="color:#f5c045;">1. Markdown Block Styling</span>
#
# This is a sample markdown cell. Notice how the background, borders, and text colours follow the **Lucra Science dark/navy/cyan/gold theme**.
#
# **Features shown:**
# - Gold header
# - White text
# - Cyan links (example: [Lucra Science](https://lucrascience.com))
# - Smooth Lucra-styled text block
#
# You can use these cells to create documentation, training modules, marketing demos, or interactive reports.

# %% [markdown]
# ## <span style="color:#f5c045;">2. Code Cell Styling</span>
# Below is a simple Python example which displays Lucra-themed colours in the code area, syntax highlighting, gutter, and output region.

# %%
message = "Lucra Science Theme Test Successful!"
print(message)
# Out:
# Lucra Science Theme Test Successful!

# %% [markdown]
# ## <span style="color:#f5c045;">3. Data Example</span>
# A simple pandas dataframe to demonstrate output styling.

# %%
import pandas as pd

df = pd.DataFrame({
    "Feature": ["Speed", "Brand Colour", "Quality"],
    "Value": ["Fast", "Navy / Cyan / Gold", "Premium"]
})
df
# Out:
#         Feature              Value
# 0         Speed               Fast
# 1  Brand Colour  Navy / Cyan / Gold
# 2       Quality            Premium

# %% [markdown]
# ---
# ## <span style="color:#f5c045;">4. Footer</span>
#
# <span style="color:#00e5ff; font-weight:600;">Lucra Science</span> – Engineering Tomorrow’s Innovation.
#
# Website: https://lucrascience.com
#
# If you are seeing this on Binder, your **custom theme is working correctly**.
